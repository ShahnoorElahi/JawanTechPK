# %%
# Task 8: Identify if number is Even or Odd
num = int(input("Enter a number to check: "))

if (num % 2) == 0:
    print(f"{num} is an Even number.")
else:
    print(f"{num} is an Odd number.")
# Out:
# Enter a number to check:  44
# 44 is an Even number.
