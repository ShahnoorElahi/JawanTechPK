# %%
# Create a sample list
my_list = ["Apple", "Banana", "Cherry", "Date", "Elderberry"]

# Get the length using the len() function
list_length = len(my_list)

# Print the result
print("The length of the list is:", list_length)
# Out:
# The length of the list is: 5
