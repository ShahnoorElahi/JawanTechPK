# %%
# Create a list of numbers
numbers = [10, 20, 30, 40, 50]

# Calculate the sum using the built-in sum() function
total_sum = sum(numbers)

# Print the result
print("The sum of all items is:", total_sum)
# Out:
# The sum of all items is: 150
