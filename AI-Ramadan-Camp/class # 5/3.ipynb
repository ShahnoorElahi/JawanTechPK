# %%
# task_3_add_key.py

# Creating an initial dictionary
student_data = {
    "name": "Ali",
    "course": "Python"
}

print("Original Dictionary:", student_data)

# Adding a new key-value pair
student_data["assignment_no"] = 3

print("Updated Dictionary:", student_data)
# Out:
# Original Dictionary: {'name': 'Ali', 'course': 'Python'}
# Updated Dictionary: {'name': 'Ali', 'course': 'Python', 'assignment_no': 3}
